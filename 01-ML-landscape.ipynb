# %% [markdown]
# # Chapter 1 Machine Learning Landscape
#
# ## Supervised Learning Vs Unsupervised Leaerning
#
# **Supervised Learning**
# Data has labels to train the model. Regression, Classification
#
# **Unsupervised Learning**
# Data has no lables. It usually used to find paterns in the data. Clustering
#
# **Semisupervised Learning**
# It is the combo of both. Some fields use labels and others doesn't.
#
# **Reinforcement Learning**
# It rewards or punish the model to train.
#
#
# ## Practical
#
# Importing Iris

# %%
from sklearn.datasets import load_iris

# %% [markdown]
# Importing pandas and Matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Iris dataframe

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns= iris.feature_names)
df["target"]= iris.target
print(df.head())
print(df['target'].value_counts())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %%
plt.scatter(df['sepal length (cm)'], df['sepal width (cm)'], c=df['target'])
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()
